# %%
import pandas as pd
import os

df=pd.read_csv("../data/tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df=pd.read_csv("../data/loan_dataset.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df=pd.read_table("../data/loan_dataset.csv",delimiter=",")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ReadJSON

# %%
data='{"name":["chinnu","chanti","banti"],"age":[22,25,28]}' # json
# data = '{"name":["Amit","Sara"], "age":[25,30]}'
df=pd.read_json(data)
print(df)
# Out:
#      name  age
# 0  chinnu   22
# 1  chanti   25
# 2   banti   28
# /var/folders/1p/j0f7xvr91cgdwsyvj_1fs0q80000gn/T/ipykernel_2042/3334902029.py:3: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df=pd.read_json(data)

# %%
pip install lxml
# Out:
# ...
#      |████████████████████████████████| 8.6 MB 8.9 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
url="https://www.worldometers.info/world-population/"
df=pd.read_html(url)
df

# %%
# data='{"name":["chinnu","chanti","banti"],"age":[22,25,28]}' # This is json
# df = pd.reac_json(data) # Reading Json

data={ # This is dictionaru
    "name":["chinnnu","chanti","banti"],
    "age":[22,25,28],
    "city":["hyd","Hyd","Nagpur"]
}


df=pd.DataFrame(data) # Reading data frame from Dictionary
df
# Out:
#       name  age    city
# 0  chinnnu   22     hyd
# 1   chanti   25     Hyd
# 2    banti   28  Nagpur

# %%
df.to_csv("output.csv",index=False)
df.to_csv("output1.csv",index=True)

# %%
df.to_excel("outpu_excel.xlsx",index=False,sheet_name="employee")
df.to_excel("outpu_excel1.xlsx",index=False)
df.to_excel("outpu_excel2.xlsx",index=True)

# %%
df.to_json("output_json")
df.to_json("output_json1",orient="records")
