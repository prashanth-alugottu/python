# %%
#Function ==>Outside the class 
# #Method ==> In side the class
#Every Declaration starts with def
#Constructors in PYTHON
#It is a special method

#Name of the constructor _init__
#It will be executed automatically at the time of object creation
#the main advantage of the constructor is to declare and initialize instance variables
#It can take at least one argument
#Constructors are two types:
# Parameterized
# Non-Parameterized

# %%
class Banking():
    def Login(self):
        print("LoginRequiredForBanking")
        print("Thank U")
        
class OnlineBanking():
    def Login(self):
        print("LoginRequiredForBanking")
        print("Thank U")
    def Online(self):
        print("Welcome to Online Banking")
        print("Secured Banking")
        
class MobileBanking():
    def Login(self):
        print("LoginRequiredForBanking")
        print("Thank U")
    def MBanking(self):
        print("Welcome to Touch Banking")
        print("It is More Comfort and AnyWhere Banking")
        
class PhoneBanking():
    def Login(self):
        print("LoginRequiredForBanking")
        print("Thank U")
    def PBanking(self):
        print("Welcome to Phone Banking")
        print("It is Only for Senior Citizens")
        print("Thank U")

#Creating Instance or Object
PP=PhoneBanking()
PP.Login()
PP.PBanking()
MM=MobileBanking()
MM.Login()
MM.MBanking()
OO=OnlineBanking()
OO.Login()
OO.Online()
# Out:
# LoginRequiredForBanking
# Thank U
# Welcome to Phone Banking
# It is Only for Senior Citizens
# Thank U
# LoginRequiredForBanking
# Thank U
# Welcome to Touch Banking
# It is More Comfort and AnyWhere Banking
# LoginRequiredForBanking
# Thank U
# Welcome to Online Banking
# Secured Banking

# %%
class animal:
    def eating(self):
        print("Animal is eating")
        
class dog:
    def sound(self):
        print("dog  is sounding")
        
d=dog()
d.sound()
d.eating()
# Out:
# dog  is sounding
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 11
#       9 d=dog()
#      10 d.sound()
# ---> 11 d.eating()
#
# AttributeError: 'dog' object has no attribute 'eating'

# %%
# 1. Single Inheritance :

class animal:
    def eating(self):
        print("Animal is eating")
        
class dog(animal):
    def sound(self):
        print("dog  is sounding")
        
d=dog()
d.sound()
d.eating()
# Out:
# dog  is sounding
# Animal is eating

# %%
# 2. Multi level Inheritance :

class Student():#Super Class
    def getStudent(self):
        self.name=input("Name: ")
        self.myword="from stu"

class Subjects(Student):#Derived Class-1
    def getMarks(self):
        self.StudentClass=input("Class: ")
        print("Enter the marks of the respective subjects:")
        self.Programming=int(input("Programming: "))
        self.myword="from sub"
    

class Marks(Subjects):#Derived Class-2
    def Display(self):
        print("\n Name is: ",self.name)
        print("Class Name: ",self.StudentClass)
        print("My words : ",self.myword)

MM=Marks()
MM.getStudent()
MM.getMarks()
MM.Display()
# Out:
# Enter the marks of the respective subjects:
#
#  Name is:  chinnu
# Class Name:  1
# My words :  from sub

# %%
# 3. Multiple Inheritance
class First():
    def a(self):
        print("Iam from First A")
class Second():
    def b(self):
        print("I am from Second B")

class Multi(First,Second):
    def c(self):
        print("I am from Multi and C")
        
m=Multi()
m.a()
m.b()
m.c()
# Out:
# Iam from First A
# I am from Second B
# I am from Multi and C

# %%
# super() usecase

class First():
    def __init__(self):
        print("I am from First init")
    def a():
        print("I am from First a")
        
class Second():
    def __init__(self):
        super().__init__()
        print("I am from Second init")
    def b():
        print("I am from Second b")
        
class Third(Second,First):
    def __init__(self):
        super().__init__()
        print("I am from Third init")
    def c():
        print("I am from Third c")
        
t=Third()
Third.mro()
# Out:
# I am from First init
# I am from Second init
# I am from Third init
# [__main__.Third, __main__.Second, __main__.First, object]

# %%
class A:
    def process(self):
        print('A process()')
class B:
    def process(self):
        print('B process()')
class C(A, B):
    def process(self):
        print('C process()')
class D(C,B):
    pass

obj = D()
obj.process() 
print(D.mro()) # Methos resolution order
# Out:
# C process()
# [<class '__main__.D'>, <class '__main__.C'>, <class '__main__.A'>, <class '__main__.B'>, <class 'object'>]

# %%
# Lets change the hierarchy. We create B and C from A and then D from B and C. Method process() is present in both A and C.
class A:
    def process(self):
        print('A process()')

class B(A):
    pass

class C(A):
    def process(self):
        print('C process()')

class D(B,C):
    pass

obj = D()
obj.process()
D.mro()
# Out:
# C process()
# [__main__.D, __main__.B, __main__.C, __main__.A, object]

# %%
# There are cases when Python cannot construct MRO owing to complexity of hierarchy.

class A:
    def process(self):
        print('A process()')

class B(A):
    def process(self):
        print('B process()')

class C(A, B):
    pass

obj = C()
obj.process()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 11
#       8     def process(self):
#       9         print('B process()')
# ---> 11 class C(A, B):
#      12     pass
#      14 obj = C()
#
# TypeError: Cannot create a consistent method resolution
# order (MRO) for bases A, B

# %%
class Employee():
    def Set1(self,empid,name,salary):
        self.empid=empid
        self.name=name
        self.salary=salary

class Fitness():
    def Set2(self,height,weight, bloodGrp):
        self.height=height
        self.weight=weight
        self.bloodGrp=bloodGrp
        
class Company(Employee,Fitness):
    def Set3(self,Company,dep):
        self.Company=Company
        self.dep=dep

    def Display(self):
        print("ID is: ",self.empid)
        print("Emp Name is: ",self.name)
        print("Salary is: ",self.salary)
        print("Height is: ",self.height)
        print("Weight is: ",self.weight)
        print("Blood Group is: ",self.bloodGrp)
        print()
        print("Company is: ",self.Company)
        print("Department is: ",self.dep)

CC=Company()
print(Company.mro())
CC.Set1(101,"Raju",70000)
CC.Set2(145,50,"B-")
CC.Set3("IBM","Software")    
CC.Display()
# Out:
# [<class '__main__.Company'>, <class '__main__.Employee'>, <class '__main__.Fitness'>, <class 'object'>]
# ID is:  101
# Emp Name is:  Raju
# Salary is:  70000
# Height is:  145
# Weight is:  50
# Blood Group is:  B-
#
# Company is:  IBM
# Department is:  Software

# %%
# If you want to execute both __init__ classes,super() function required

class First():
    def __init__(self):
        print("init of First Class")
    def A(self):
        print("I am in First PClass")
class Second(First):
    def __init__(self):
        super().__init__()
        print("init of Second Class")
    def B(self):
        print("I am in Second PClass")
class Third(Second):
    def C(self):
        print("I am in Child Class")

SS=Second()
# Out:
# init of First Class
# init of Second Class

# %%
# Hierarchical Inheritance:

class Details():
    def __init__(self):
        self.Id=""
        self.Name=""
    def SetData(self,Id,Name):
        self.Id=Id
        self.Name=Name
    def ShowData(self):
        print("ID: ",self.Id)
        print("Name: ",self.Name)

class Employee(Details):
    def __init__(self):
        self.Company=""
        self.Dept=""
    def SetEmployee(self,Id,Name,Comp,Dept):
        self.SetData(Id,Name)
        self.Company=Comp
        self.Dept=Dept
    def ShowEmployee(self):
        self.ShowData()
        print("Company: ",self.Company)
        print("Department: ",self.Dept)

class Doctor(Details):
    def __init__(self):
        self.Hospital=""
        self.Dept=""
    def SetEmployee(self,Id,Name,Hos,Dept):
        self.SetData(Id,Name)
        self.Hospital=Hos
        self.Dept=Dept
    def ShowEmployee(self):
        self.ShowData()
        print("Hospital: ",self.Hospital)
        print("Department: ",self.Dept)

print("Employee Class Object")
EE=Employee()
EE.SetEmployee(101,"Raju","TCS","IT")
EE.ShowEmployee()

print("\n Doctor Class Object: ")
DD=Doctor()
DD.SetEmployee(101,'RaviKumar',"Prime","Dental")
DD.ShowEmployee()
# Out:
# Employee Class Object
# ID:  101
# Name:  Raju
# Company:  TCS
# Department:  IT
#
#  Doctor Class Object:
# ID:  101
# Name:  RaviKumar
# Hospital:  Prime
# Department:  Dental

# %%
class Banking():
    count=0
    def __init__(self):
        Banking.count+=1
#Instance Method
B1=Banking()
B2=Banking()
B3=Banking()
print ("The Number of Customers: ",Banking.count)
# Out:
# The Number of Customers:  3

# %%
# one type of class declairation
class Car():
    pass
# second type of class declairation
class Car:
    pass

# third type of class declairation
class Car(object):
    pass

# %%
class Banking():
    #in instance methods, it is mandatory.
    def customer(self):
        print("Welcome to Banking")
        print(id(self))
        
b = Banking()
b.customer()
print(id(b))
# Out:
# Welcome to Banking
# 4446324240
# 4446324240

# %%
class Banking():
    #in instance methods, it is mandatory.
    def customer(x): # you can give any letter but first param will taken as self only
        print("Welcome to Banking")
        print(id(x))
        
b = Banking()
b.customer()
print(id(b))
# Out:
# Welcome to Banking
# 4360112736
# 4360112736

# %%
class Banking():
    #in instance methods, it is mandatory.
    def customer(x,y,z): # you can give any letter but first param will taken as self only
        print(f"Welcome to Banking {x} \n{y} and {z}")
        print(id(x))
        
b = Banking()
b.customer(1,2)
print(id(b))
# Out:
# Welcome to Banking <__main__.Banking object at 0x109014c70>
# 1 and 2
# 4446047344
# 4446047344

# %%
class Banking():
    def __init__(self):
        print("Welcome to Banking")
        
Banking()
# Out:
# Welcome to Banking

# %%
class Banking():
    # Special method
    def __init__(self,x):
        print("Welcome to Banking",x)
    # Instance method
    def hai(self):
        print("From HAI")

# Creating obj
b=Banking(18)
b.hai()
# Out:
# Welcome to Banking 18
# From HAI

# %%
class Banking():
    count=0
    def __init__(self):
        Banking.count+=1
        
b1=Banking()
b2=Banking()
b3=Banking()
print(Banking.count)
# Out:
# 3

# %%
class Student():
    def __init__(self,name):
        self.name=name
        
    def show(self):
        print(self.name)
        
st=Student("Chinnu")
st.show()
# Out:
# Chinnu

# %%
class Test():
    def __init__(self):
        print("Hey Iam Constructor")

    def method(self):
        print("Iam from method")
        
one=Test()
two=Test()
three=Test()
one.method()
# Out:
# Hey Iam Constructor
# Hey Iam Constructor
# Hey Iam Constructor
# Iam from method

# %%
#
