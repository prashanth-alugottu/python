# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample data
data = pd.DataFrame({
    'Subject': ['Math', 'Math', 'Math', 'Science', 'Science', 'Science',
                'English', 'English', 'English'] * 2,
    'Marks': [85, 90, 78, 88, 76, 92, 80, 75, 85,
              60, 65, 70, 55, 58, 68, 72, 74, 69],
    'Gender': ['Male']*9 + ['Female']*9
})

# %%
print("1. Barplot – Mean values with confidence intervals")
print(data)
sns.barplot(x="Subject", y="Marks", data=data)
plt.show()
# Out:
# 1. Barplot – Mean values with confidence intervals
#     Subject  Marks  Gender
# 0      Math     85    Male
# 1      Math     90    Male
# 2      Math     78    Male
# 3   Science     88    Male
# 4   Science     76    Male
# 5   Science     92    Male
# 6   English     80    Male
# 7   English     75    Male
# 8   English     85    Male
# 9      Math     60  Female
# 10     Math     65  Female
# 11     Math     70  Female
# 12  Science     55  Female
# 13  Science     58  Female
# 14  Science     68  Female
# 15  English     72  Female
# 16  English     74  Female
# 17  English     69  Female

# %%
print("2. Countplot – Frequency of categories")
# Shows how many students took each subject.
sns.countplot(x="Subject", data=data)
plt.show()
# Out:
# 2. Countplot – Frequency of categories

# %%
print("3. Stripplot – Scatterplot with jitter")
print(data)
sns.stripplot(x="Subject", y="Marks", data=data, jitter=True)
plt.show()
# Displays individual student marks with slight random spread.
# Out:
# 3. Stripplot – Scatterplot with jitter
#     Subject  Marks  Gender
# 0      Math     85    Male
# 1      Math     90    Male
# 2      Math     78    Male
# 3   Science     88    Male
# 4   Science     76    Male
# 5   Science     92    Male
# 6   English     80    Male
# 7   English     75    Male
# 8   English     85    Male
# 9      Math     60  Female
# 10     Math     65  Female
# 11     Math     70  Female
# 12  Science     55  Female
# 13  Science     58  Female
# 14  Science     68  Female
# 15  English     72  Female
# 16  English     74  Female
# 17  English     69  Female

# %%
print("4. Swarmplot – Scatterplot avoiding overlap")
# Similar to stripplot, but no overlap, clearer.
sns.swarmplot(x="Subject", y="Marks", data=data)
plt.show()
# Out:
# 4. Swarmplot – Scatterplot avoiding overlap

# %%
print("5. Boxplot – Statistical summary")
# Shows median, quartiles, and outliers of marks per subject.
sns.boxplot(x="Subject", y="Marks", data=data)
plt.show()
# Out:
# 5. Boxplot – Statistical summary

# %%
print("6. Violinplot – KDE + Boxplot")
# Combines distribution shape + boxplot summary.
sns.violinplot(x="Subject", y="Marks", data=data)
plt.show()
# Out:
# 6. Violinplot – KDE + Boxplot

# %%
print("7. Pointplot – Mean values with confidence intervals")
# Plots subject-wise mean marks with error bars.
sns.pointplot(x="Subject", y="Marks", data=data)
plt.show()
# Out:
# 7. Pointplot – Mean values with confidence intervals

# %%
print("8. Catplot – Flexible categorical plotting")
# Creates a categorical plot (here same as stripplot, but flexible for grids).
sns.catplot(x="Subject", y="Marks", data=data, kind="strip")
plt.show()
# Out:
# 8. Catplot – Flexible categorical plotting
