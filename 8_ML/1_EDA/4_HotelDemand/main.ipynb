# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("data/hotel_bookings.csv")
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.rename({'adults':'num_adults','children':'num_children','babies':'num_babies'},inplace=True,axis=1)
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'num_adults', 'num_children', 'num_babies',
#        'meal', 'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# ## 1. Nan

# %% [markdown]
# ### Checking NaN

# %%
# NaN
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   num_adults                      119390 non-null  int64
#  10  num_children                    119386 non-null  float64
#  11  num_babies                      119390 non-null  int64
# ...

# %%
# num_children -> 119386 --> fill the NaN with the mode
# country      ->118902-119390=488(Nan) --> 
# agent        ->103050-119390=16340(Nan) --> 
# company      -> 6797-119390=112593(Nan) --> 

# Instead of the above calculation please folllow below

df.isnull().sum()*100/len(df)
# Out:
# hotel                              0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# num_adults                         0.000000
# num_children                       0.003350
# num_babies                         0.000000
# meal                               0.000000
# country                            0.408744
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# assigned_room_type                 0.000000
# ...

# %% [markdown]
# ### 1. Droppoing company coz 94% NaN that will not help in any of the situations

# %%
df.drop(columns=['company'],inplace=True)
df.head(2)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  num_adults  ...  \
# 0                        0                     0           2  ...
# 1                        0                     0           2  ...
#
#    booking_changes  deposit_type agent days_in_waiting_list customer_type  \
# 0                3    No Deposit   NaN                    0     Transient
# 1                4    No Deposit   NaN                    0     Transient
#
#    adr  required_car_parking_spaces  total_of_special_requests  \
# 0  0.0                            0                          0
# ...

# %% [markdown]
# ### 2. May we can fill the agent column let see the values whar are there then will do fill

# %%
df['agent'].unique()
# Out:
# array([ nan, 304., 240., 303.,  15., 241.,   8., 250., 115.,   5., 175.,
#        134., 156., 243., 242.,   3., 105.,  40., 147., 306., 184.,  96.,
#          2., 127.,  95., 146.,   9., 177.,   6., 143., 244., 149., 167.,
#        300., 171., 305.,  67., 196., 152., 142., 261., 104.,  36.,  26.,
#         29., 258., 110.,  71., 181.,  88., 251., 275.,  69., 248., 208.,
#        256., 314., 126., 281., 273., 253., 185., 330., 334., 328., 326.,
#        321., 324., 313.,  38., 155.,  68., 335., 308., 332.,  94., 348.,
#        310., 339., 375.,  66., 327., 387., 298.,  91., 245., 385., 257.,
#        393., 168., 405., 249., 315.,  75., 128., 307.,  11., 436.,   1.,
#        201., 183., 223., 368., 336., 291., 464., 411., 481.,  10., 154.,
#        468., 410., 390., 440., 495., 492., 493., 434.,  57., 531., 420.,
#        483., 526., 472., 429.,  16., 446.,  34.,  78., 139., 252., 270.,
#         47., 114., 301., 193., 182., 135., 350., 195., 352., 355., 159.,
# ...

# %% [markdown]
# 1. Not finding any similarities in the agent column so we will be filling with the -1 but in reality we have to take knowledge from the client such that what values are suitable for this NaN we have to fill with that value.
#
# 2. We can not drop it because there are so many rows will be deleted.

# %%
df[df['agent']==5]
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 25     Resort Hotel            0         78               2015
# 79     Resort Hotel            0         81               2015
# 155    Resort Hotel            0         82               2015
# 272    Resort Hotel            0         87               2015
# 300    Resort Hotel            0         36               2015
# ...             ...          ...        ...                ...
# 75021    City Hotel            1        268               2015
# 75022    City Hotel            1        268               2015
# 75023    City Hotel            1        268               2015
# 75024    City Hotel            1        268               2015
# 75025    City Hotel            1        268               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 25                  July                        27                          1
# ...

# %%
df['agent'].fillna(-1,inplace=True)
df['agent'].isnull().sum()
# Out:
# /var/folders/1p/j0f7xvr91cgdwsyvj_1fs0q80000gn/T/ipykernel_1354/3891395547.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['agent'].fillna(-1,inplace=True)
# np.int64(0)

# %% [markdown]
# ### 3. num_children

# %%
df['num_children'].isnull().sum() # There are 4 values are NaN Probabli drop
# Out:
# np.int64(4)

# %%
df['num_children'].unique() # Checking If we can do somethig
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %%
df[df['num_children'].isnull()]
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 40600  City Hotel            1          2               2015
# 40667  City Hotel            1          1               2015
# 40679  City Hotel            1          1               2015
# 41160  City Hotel            1          8               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 40600             August                        32                          3
# 40667             August                        32                          5
# 40679             August                        32                          5
# 41160             August                        33                         13
#
#        stays_in_weekend_nights  stays_in_week_nights  num_adults  ...  \
# 40600                        1                     0           2  ...
# 40667                        0                     2           2  ...
# ...

# %%
# We have to drop rows that contains num_children == Nan
df['num_children'].isnull().sum()
df.dropna(subset=['num_children'],inplace=True)
df['num_children'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 4. country

# %%
df['country'].isnull().sum()
# Out:
# np.int64(488)

# %%
df[df['country'].isnull()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 30      Resort Hotel            0        118               2015
# 4127    Resort Hotel            1          0               2016
# 7092    Resort Hotel            1          8               2016
# 7860    Resort Hotel            1         39               2016
# 8779    Resort Hotel            1          0               2016
# ...              ...          ...        ...                ...
# 65908     City Hotel            1          0               2017
# 65909     City Hotel            1          0               2017
# 65910     City Hotel            1          0               2017
# 80830     City Hotel            0          4               2015
# 101488    City Hotel            0          1               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 30                   July                        27
# 4127             February                         8
# ...

# %%
# will be filling with unknown since we cant drop coz 488 rows, we can not add random country
df['country'].fillna('unknow',inplace=True)
df['country'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119386 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119386 non-null  object
#  1   is_canceled                     119386 non-null  int64
#  2   lead_time                       119386 non-null  int64
#  3   arrival_date_year               119386 non-null  int64
#  4   arrival_date_month              119386 non-null  object
#  5   arrival_date_week_number        119386 non-null  int64
#  6   arrival_date_day_of_month       119386 non-null  int64
#  7   stays_in_weekend_nights         119386 non-null  int64
#  8   stays_in_week_nights            119386 non-null  int64
#  9   num_adults                      119386 non-null  int64
#  10  num_children                    119386 non-null  float64
#  11  num_babies                      119386 non-null  int64
# ...

# %% [markdown]
# ## 2. Data types

# %% [markdown]
# ### Checking Data types

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# num_adults                          int64
# num_children                      float64
# num_babies                          int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', 200)
# pd.set_option('display.width', None)
# pd.set_option('display.max_colwidth', None)
df.head(2)
df['is_repeated_guest'].unique()
# Out:
# array([0, 1])

# %%
print(df['is_canceled'].unique())
df=df.astype({'is_canceled':'boolean','is_repeated_guest':'boolean','num_children':'int'})
df.dtypes
# Out:
# [0 1]
# hotel                              object
# is_canceled                       boolean
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# num_adults                          int64
# num_children                        int64
# num_babies                          int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                 boolean
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# ### 3. Bins Columns

# %%
df['lead_time'].unique()
# Out:
# array([342, 737,   7,  13,  14,   0,   9,  85,  75,  23,  35,  68,  18,
#         37,  12,  72, 127,  78,  48,  60,  77,  99, 118,  95,  96,  69,
#         45,  40,  15,  36,  43,  70,  16, 107,  47, 113,  90,  50,  93,
#         76,   3,   1,  10,   5,  17,  51,  71,  63,  62, 101,   2,  81,
#        368, 364, 324,  79,  21, 109, 102,   4,  98,  92,  26,  73, 115,
#         86,  52,  29,  30,  33,  32,   8, 100,  44,  80,  97,  64,  39,
#         34,  27,  82,  94, 110, 111,  84,  66, 104,  28, 258, 112,  65,
#         67,  55,  88,  54, 292,  83, 105, 280, 394,  24, 103, 366, 249,
#         22,  91,  11, 108, 106,  31,  87,  41, 304, 117,  59,  53,  58,
#        116,  42, 321,  38,  56,  49, 317,   6,  57,  19,  25, 315, 123,
#         46,  89,  61, 312, 299, 130,  74, 298, 119,  20, 286, 136, 129,
#        124, 327, 131, 460, 140, 114, 139, 122, 137, 126, 120, 128, 135,
#        150, 143, 151, 132, 125, 157, 147, 138, 156, 164, 346, 159, 160,
# ...

# %%
df['lead_time'].describe() # In order to make bins by using cut() we havr to knoe min and max
# Out:
# count    119386.000000
# mean        104.014801
# std         106.863286
# min           0.000000
# 25%          18.000000
# 50%          69.000000
# 75%         160.000000
# max         737.000000
# Name: lead_time, dtype: float64

# %%
bins=[0,100,200,300,400,500,600,700,800]
labels=['0-100','101-200','201-300','301-400','401-500','501-600','601-700','701-800']
df['lead_time_binned']=pd.cut(df['lead_time'],bins=bins,labels=labels)
df[['lead_time','lead_time_binned']]
# Out:
#         lead_time lead_time_binned
# 0             342          301-400
# 1             737          701-800
# 2               7            0-100
# 3              13            0-100
# 4              14            0-100
# ...           ...              ...
# 119385         23            0-100
# 119386        102          101-200
# 119387         34            0-100
# 119388        109          101-200
# 119389        205          201-300
#
# [119386 rows x 2 columns]

# %% [markdown]
# ### Separate Columns

# %%
df.head(3)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel        False        342               2015               July
# 1  Resort Hotel        False        737               2015               July
# 2  Resort Hotel        False          7               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  num_adults  num_children  \
# 0                        0                     0           2             0
# 1                        0                     0           2             0
# 2                        0                     1           1             0
#
#    num_babies meal country market_segment distribution_channel  \
# ...
